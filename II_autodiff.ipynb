# %% [markdown]
# # Differentiable Physics II:  Automatic Differentiation of Verlet Integration

# %% [markdown]
# Before we have used a simple force field which was defined as:
#
# $$ F(x) = -kx $$
#
# Moving forward we use a set of $K$ attractors each with a position $k_i$. The force function is then defined as:
#
# $$ F(x) = \sum_{i=1}^N \frac{k_i - x}{||k_i - x||^2} $$
#
# Finding the derivate of the force field is a bit more involved but it is still possible to do it analytically. However we can use an autograd library such as jax, to get the gradient of the loss of the solver.

# %%
import matplotlib.pyplot as plt
import jax.numpy as jnp
from jax import value_and_grad, jit, random
from jax.typing import ArrayLike

key = random.PRNGKey(0)

n_attractors = 5
attractors = random.uniform(key, (n_attractors, 2), minval=-1, maxval=1, dtype=jnp.float32)

plt.figure(figsize=(5,5))
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.grid()

plt.scatter(attractors[:,0], attractors[:,1], c='orange', marker='x', s=40, label='attractor')
plt.legend()
plt.title('Randomly sampled attractors')
# Out:
# Text(0.5, 1.0, 'Randomly sampled attractors')

# %%
from functools import partial

@jit
def force(x : jnp.ndarray, attractors : jnp.ndarray) -> jnp.ndarray:
    f = jnp.zeros_like(x)

    for a in attractors:
        d = a - x
        f += d / jnp.linalg.norm(d)**2

    return f

@partial(jit, static_argnames=('dt', 'm'))
def verlet_step(
    x : jnp.ndarray,
    v : jnp.ndarray,
    dt : float,
    m : float, 
    attractors : jnp.ndarray) -> tuple[jnp.ndarray, jnp.ndarray]:

    x_fwd = jnp.asarray(x) + (v * dt) + (0.5 * force(x, attractors) * dt * dt / m)
    v_fwd = jnp.asarray(v) + (0.5 * (force(x, attractors) + force(x_fwd, attractors)) * dt / m)

    return x_fwd, v_fwd

# %% [markdown]
# A simple forward simulation of the system with 300 iterations:

# %%
x0_guess = jnp.array([-0.5, -0.7], dtype=jnp.float32)
v0_guess = jnp.array([0.2, -0.8], dtype=jnp.float32)

xn_star = jnp.array([0.5, 0.7], dtype=jnp.float32)

n_iterations = 50
dt = 0.03
m = 1.0

x = x0_guess.copy()
v = v0_guess.copy()

xs = jnp.zeros((n_iterations, 2), dtype=jnp.float32)
vs = jnp.zeros((n_iterations, 2), dtype=jnp.float32)

for i in range(n_iterations):
    x, v = verlet_step(x, v, dt, m, attractors)
    xs = xs.at[i, :].set(x.copy())
    vs = vs.at[i, :].set(v.copy())

plt.figure(figsize=(5,5))

plt.xlim(-1,1)
plt.ylim(-1,1)

plt.grid()

plt.scatter(attractors[:,0], attractors[:,1], c='orange', marker='o', s=40, label='attractor')  
plt.scatter(xn_star[0], xn_star[1], c='green', marker='x', s=40, label='target')
plt.scatter(x0_guess[0], x0_guess[1], c='blue', marker='x', s=40, label='initial guess')
plt.scatter(xs[:,0], xs[:,1], c='red', marker='o', s=1, label='trajectory')

plt.legend()

# %% [markdown]
# To find the appropriate initial conditions we use the gradient descent method again. This time we perform all the differentiation using jit.

# %%
@jit
def loss(x : jnp.ndarray, target : jnp.ndarray) -> float:
    return jnp.mean((target - x) ** 2)

# %% [markdown]
# What is special about the force function, is how the velocity can increase exponentially when the distance between the attractor and the particle is small. This is a problem as the loss surface is very uneven and bumpy.

# %%
grid_size = 50
x = jnp.linspace(-1, 1, grid_size)
y = jnp.linspace(-1, 1, grid_size)

X, Y = jnp.meshgrid(x, y)
x0s = jnp.stack([X, Y], axis=-1).reshape(-1, 2)

loss_grid = jnp.zeros((grid_size, grid_size), dtype=jnp.float32)

for i, x0 in enumerate(x0s):
    x = x0.copy()
    v = jnp.array([0.0, 0.0], dtype=jnp.float32)
    for j in range(n_iterations):
        x, v = verlet_step(x, v, dt, m, attractors)
    
    loss_grid = loss_grid.at[i // grid_size, i % grid_size].set(loss(x, xn_star))

fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(8,8))

loss_grid = jnp.log(loss_grid)

ax.plot_surface(X, Y, loss_grid, cmap='inferno', edgecolor='none', alpha=1.0)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('loss')
ax.set_title('Loss landscape with zero initial velocity')

# %% [markdown]
# The actual simulation method:

# %%
def verlet_simulation(
        x0 : jnp.ndarray, 
        v0 : jnp.ndarray, 
        xn_star : jnp.ndarray,
        dt : float, 
        n : int, 
        m : float, 
        attractors : jnp.ndarray) -> float:
    x = x0.copy()
    v = v0.copy()
    
    for i in range(n):
        x, v = verlet_step(x, v, dt, m, attractors)

    return loss(x, xn_star) + 0.1 * jnp.mean(v ** 2) + 0.01 * jnp.mean(x ** 2)

# %% [markdown]
# ## Finding initial position and velocity
#
# We use the ``value_and_grad`` method from jax to get the gradient and the actual loss value.

# %%
loss_grad = value_and_grad(verlet_simulation, argnums=(0, 1))

# %%
optimization_steps = 50

learning_rate = 0.2

x0 = x0_guess.copy()
v0 = v0_guess.copy()

losses = jnp.zeros(optimization_steps, dtype=jnp.float32)
x0s = jnp.zeros((optimization_steps, 2), dtype=jnp.float32)
v0s = jnp.zeros((optimization_steps, 2), dtype=jnp.float32)

grad_x_momentum = jnp.zeros_like(x0)
grad_v_momentum = jnp.zeros_like(v0)

beta = 0.1

for i in range(optimization_steps):

    loss_x, (grad_x, grad_v) = loss_grad(x0, v0, xn_star, dt, n_iterations, m, attractors)

    # normalize gradients
    grad_x /= jnp.linalg.norm(grad_x) 
    grad_v /= jnp.linalg.norm(grad_v)

    grad_x_momentum = beta * grad_x_momentum + (1-beta) * -grad_x * learning_rate
    grad_v_momentum = beta * -grad_v * learning_rate + (1-beta) * grad_v_momentum

    x0 += grad_x_momentum * learning_rate
    v0 += grad_v_momentum * learning_rate

    losses = losses.at[i].set(loss_x)

    x0s = x0s.at[i, :].set(x0.copy())
    v0s = v0s.at[i, :].set(v0.copy())

    learning_rate *= 0.97

    print(F"loss {loss_x} | grad_x {grad_x} | grad_v {grad_v} | lr {learning_rate}")
# Out:
# loss 1.0930849313735962 | grad_x [0.76559144 0.6433272 ] | grad_v [ 0.9681517  -0.25036424] | lr 0.194
# loss 1.2925957441329956 | grad_x [-0.82444835  0.5659372 ] | grad_v [-0.8006078   0.59918875] | lr 0.18818000000000001
# loss 1.143263339996338 | grad_x [-0.40533385 -0.9141687 ] | grad_v [ 0.5154421 -0.8569244] | lr 0.18253460000000002
# loss 1.1155242919921875 | grad_x [0.36332446 0.93166274] | grad_v [-0.02690471  0.99963796] | lr 0.177058562
# loss 1.0250569581985474 | grad_x [0.40941077 0.9123502 ] | grad_v [-0.3432755  0.9392348] | lr 0.17174680514
# loss 1.4690560102462769 | grad_x [0.4004199 0.9163317] | grad_v [-0.6141408   0.78919643] | lr 0.16659440098579997
# loss 1.068299651145935 | grad_x [0.50021905 0.8658989 ] | grad_v [-0.5772832   0.81654394] | lr 0.16159656895622598
# loss 0.8664100170135498 | grad_x [0.52239776 0.85270184] | grad_v [-0.47683352  0.87899363] | lr 0.1567486718875392
# loss 0.6628991961479187 | grad_x [0.6589936  0.75214845] | grad_v [-0.533093    0.84605664] | lr 0.152046211730913
# loss 0.42429298162460327 | grad_x [0.93348765 0.35860956] | grad_v [-0.9648694   0.26273018] | lr 0.1474848253789856
# loss 0.34876370429992676 | grad_x [0.6806203  0.73263633] | grad_v [0.12095155 0.9926584 ] | lr 0.14306028061761603
# loss 0.22232480347156525 | grad_x [ 0.07089049 -0.9974841 ] | grad_v [-0.89598715 -0.44408   ] | lr 0.13876847219908753
# loss 0.22637939453125 | grad_x [0.56355846 0.82607627] | grad_v [-0.12979518  0.9915408 ] | lr 0.1346054180331149
# loss 0.21105478703975677 | grad_x [-0.15170148 -0.9884263 ] | grad_v [-0.5764533 -0.81713  ] | lr 0.13056725549212145
# loss 0.16163380444049835 | grad_x [0.61340564 0.7897681 ] | grad_v [-0.5407031  0.8412135] | lr 0.1266502378273578
# loss 0.20448143780231476 | grad_x [-0.22285318 -0.974852  ] | grad_v [-0.44060928 -0.897699  ] | lr 0.12285073069253706
# loss 0.1191595196723938 | grad_x [0.87824124 0.47821784] | grad_v [-0.89037883  0.4552204 ] | lr 0.11916520877176094
# loss 0.15420649945735931 | grad_x [-0.28048715 -0.9598577 ] | grad_v [-0.5593562 -0.8289274] | lr 0.1155902525086081
# loss 0.08757397532463074 | grad_x [0.564963  0.8251163] | grad_v [-0.57004166  0.82161576] | lr 0.11212254493334986
# loss 0.1260995864868164 | grad_x [-0.30982128 -0.9507948 ] | grad_v [-0.5776606 -0.816277 ] | lr 0.10875886858534936
# loss 0.060927607119083405 | grad_x [0.56317395 0.82633835] | grad_v [-0.67798483  0.7350759 ] | lr 0.10549610252778888
# loss 0.09814046323299408 | grad_x [-0.32623518 -0.94528866] | grad_v [-0.5842302 -0.811588 ] | lr 0.10233121945195521
# loss 0.04307142645120621 | grad_x [0.5266206 0.8501004] | grad_v [-0.7020974  0.7120809] | lr 0.09926128286839656
# loss 0.0729040801525116 | grad_x [-0.33266324 -0.9430457 ] | grad_v [-0.5537905  -0.83265597] | lr 0.09628344438234465
# loss 0.0345107726752758 | grad_x [0.42670316 0.9043917 ] | grad_v [-0.48748744  0.87313   ] | lr 0.09339494105087431
# loss 0.058021362870931625 | grad_x [-0.32514766 -0.9456633 ] | grad_v [-0.3760788 -0.9265877] | lr 0.09059309281934808
# loss 0.03407001495361328 | grad_x [0.30739507 0.95158195] | grad_v [0.96513754 0.26174313] | lr 0.08787530003476764
# loss 0.05526673048734665 | grad_x [-0.29197484 -0.9564259 ] | grad_v [ 0.18852721 -0.982068  ] | lr 0.08523904103372461
# loss 0.037063129246234894 | grad_x [0.11504277 0.9933606 ] | grad_v [ 0.96564794 -0.25985387] | lr 0.08268186980271287
# loss 0.05723610520362854 | grad_x [-0.25846162 -0.9660215 ] | grad_v [ 0.6189274  -0.78544813] | lr 0.08020141370863149
# loss 0.0390600860118866 | grad_x [0.2723658 0.9621938] | grad_v [ 0.9955736  -0.09398492] | lr 0.07779537129737255
# loss 0.05618021637201309 | grad_x [-0.28141636 -0.9595857 ] | grad_v [ 0.63962525 -0.7686869 ] | lr 0.07546151015845137
# loss 0.039254557341337204 | grad_x [0.2901988 0.9569664] | grad_v [ 0.99996847 -0.00794111] | lr 0.07319766485369783
# loss 0.05028148368000984 | grad_x [-0.31595322 -0.9487748 ] | grad_v [ 0.55373365 -0.8326938 ] | lr 0.0710017349080869
# loss 0.03822372853755951 | grad_x [0.2629467  0.96481043] | grad_v [ 0.99952775 -0.03072916] | lr 0.06887168286084429
# loss 0.04279204085469246 | grad_x [-0.3403148  -0.94031155] | grad_v [ 0.45282936 -0.8915972 ] | lr 0.06680553237501896
# loss 0.03674180805683136 | grad_x [0.20161101 0.97946566] | grad_v [ 0.99728256 -0.0736719 ] | lr 0.06480136640376839
# loss 0.036848265677690506 | grad_x [-0.358504  -0.9335282] | grad_v [ 0.3891909 -0.9211571] | lr 0.06285732541165534
# loss 0.035790570080280304 | grad_x [0.3288673 0.9443762] | grad_v [0.751082  0.6602089] | lr 0.06097160564930568
# loss 0.03396731987595558 | grad_x [-0.37498432 -0.9270311 ] | grad_v [ 0.39623433 -0.9181494 ] | lr 0.05914245747982651
# loss 0.036003246903419495 | grad_x [0.3890778  0.92120486] | grad_v [0.12511705 0.99214196] | lr 0.05736818375543171
# loss 0.03317645564675331 | grad_x [-0.40077564 -0.9161762 ] | grad_v [ 0.41185653 -0.9112487 ] | lr 0.05564713824276876
# loss 0.036833614110946655 | grad_x [0.40472296 0.9144394 ] | grad_v [-0.00131337  0.9999991 ] | lr 0.0539777240954857
# loss 0.03335689753293991 | grad_x [0.40232545 0.9154967 ] | grad_v [-0.50482595  0.86322117] | lr 0.052358392372621125
# loss 0.03726605325937271 | grad_x [-0.33662903 -0.94163734] | grad_v [-0.41542834 -0.9096259 ] | lr 0.05078764060144249
# loss 0.033617161214351654 | grad_x [-0.28587267 -0.9582676 ] | grad_v [-0.9950528  -0.09934722] | lr 0.04926401138339921
# loss 0.03648964688181877 | grad_x [0.40946716 0.91232485] | grad_v [-0.11116955  0.9938014 ] | lr 0.04778609104189723
# loss 0.03380892425775528 | grad_x [0.4369221  0.89949936] | grad_v [-0.6523546   0.75791395] | lr 0.04635250831064031
# loss 0.035728320479393005 | grad_x [-0.33718127 -0.94143975] | grad_v [-0.5845076  -0.81138825] | lr 0.044961933061321104
# loss 0.0337146557867527 | grad_x [-0.10982818 -0.9939506 ] | grad_v [-0.97594655  0.21800977] | lr 0.04361307506948147

# %%
plt.figure(figsize=(5,3))

plt.plot(losses, label="loss position", color="green", linestyle="dashed")
# y axis log
plt.yscale("log")

plt.legend()

plt.title("Gradient descent")
plt.xlabel("optimization step")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
import matplotlib.patches as mpatches

plt.figure(figsize=(5,5))

plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

plt.grid()

for j in range(0, optimization_steps, 4):
    x = x0s[j, :].copy()
    v = v0s[j, :].copy()

    xs = jnp.zeros((n_iterations, 2), dtype=jnp.float32)
    vs = jnp.zeros((n_iterations, 2), dtype=jnp.float32)

    for i in range(n_iterations):
        x, v = verlet_step(x, v, dt, m, attractors)
        xs = xs.at[i, :].set(x.copy())
        vs = vs.at[i, :].set(v.copy())

    plt.scatter(xs[:,0], xs[:,1], c='red', marker='o', s=0.2, label='trajectory', alpha=0.3)

plt.scatter(attractors[:,0], attractors[:,1], c='orange', marker='o', s=40, label='attractor')  
plt.scatter(xn_star[0], xn_star[1], c='green', marker='x', s=40, label='target')


red_patch = mpatches.Patch(color='red', label='trajectories')
green_patch = mpatches.Patch(color='green', label='target position')
orange_patch = mpatches.Patch(color='orange', label='attractor')
handles = [red_patch, green_patch, orange_patch]

plt.legend(handles=handles)

# %% [markdown]
# ## Finding optimal initial conditions for the velocity only
#
# Instead of differentiating the the loss function with respect to the position and the velocity, we only differentiate with respect to the velocity this time.

# %%
def verlet_simulation_vel(
        v0 : jnp.ndarray, 
        x0 : jnp.ndarray, 
        xn_star : jnp.ndarray,
        dt : float, 
        n : int, 
        m : float, 
        attractors : jnp.ndarray) -> float:
    x = x0.copy()
    v = v0.copy()
    
    for i in range(n):
        x, v = verlet_step(x, v, dt, m, attractors)

    return loss(x, xn_star)

# %%
loss_grad_vel_only = value_and_grad(verlet_simulation_vel, argnums=(0))

# %%
optimization_steps = 40

learning_rate = 0.3

x0 = x0_guess.copy()
v0 = jnp.zeros_like(x0)

print(xn_star)

losses = jnp.zeros(optimization_steps, dtype=jnp.float32)
v0s = jnp.zeros((optimization_steps, 2), dtype=jnp.float32)
x0s = jnp.repeat(x0_guess[None, :], optimization_steps, axis=0)

grad_v_momentum = jnp.zeros_like(v0)

beta = 0.1

for i in range(optimization_steps):

    loss_x, grad_v = loss_grad_vel_only(v0, x0, xn_star, dt, n_iterations, m, attractors)

    # normalize gradients
    grad_v /= jnp.linalg.norm(grad_v)

    grad_v_momentum = beta * -grad_v * learning_rate + (1-beta) * grad_v_momentum

    v0 += grad_v_momentum * learning_rate * jnp.minimum(loss_x, 1)

    print(F"loss {loss_x} | grad_v {grad_v} | lr {learning_rate}")
    losses = losses.at[i].set(loss_x)

    v0s = v0s.at[i, :].set(v0.copy())

    #learning_rate *= 0.97
# Out:
# [0.5 0.7]
# loss 1.244605302810669 | grad_v [-0.877504    0.47956946] | lr 0.3
# loss 1.147294282913208 | grad_v [-0.7464777  0.6654104] | lr 0.3
# loss 1.187134861946106 | grad_v [ 0.34194195 -0.93972105] | lr 0.3
# loss 2.0219504833221436 | grad_v [-0.24823725 -0.9686993 ] | lr 0.3
# loss 1.2105382680892944 | grad_v [ 0.78879786 -0.61465275] | lr 0.3
# loss 1.2672513723373413 | grad_v [0.25049102 0.96811897] | lr 0.3
# loss 1.265207290649414 | grad_v [-0.1863272  -0.98248774] | lr 0.3
# loss 1.2390022277832031 | grad_v [-0.3681538 -0.9297649] | lr 0.3
# loss 1.4397318363189697 | grad_v [-0.40852702 -0.91274625] | lr 0.3
# loss 1.8748865127563477 | grad_v [-0.4249297  -0.90522635] | lr 0.3
# loss 0.7753311991691589 | grad_v [-0.7549941 -0.6557317] | lr 0.3
# loss 0.0827789306640625 | grad_v [-0.9429953  -0.33280617] | lr 0.3
# loss 0.05224364250898361 | grad_v [-0.9623425  -0.27183992] | lr 0.3
# loss 0.03430710732936859 | grad_v [-0.96808636 -0.25061688] | lr 0.3
# loss 0.023339098319411278 | grad_v [-0.965434  -0.2606475] | lr 0.3
# loss 0.01657791994512081 | grad_v [-0.95541364 -0.29527068] | lr 0.3
# loss 0.012364959344267845 | grad_v [-0.935573   -0.35313335] | lr 0.3
# loss 0.009703033603727818 | grad_v [-0.8983968  -0.43918478] | lr 0.3
# loss 0.008005630224943161 | grad_v [-0.8252222  -0.56480825] | lr 0.3
# loss 0.006926982197910547 | grad_v [-0.6697082 -0.7426244] | lr 0.3
# loss 0.006262272130697966 | grad_v [-0.34481522 -0.93867064] | lr 0.3
# loss 0.005873044952750206 | grad_v [ 0.13251665 -0.9911808 ] | lr 0.3
# loss 0.005652046762406826 | grad_v [ 0.5030426 -0.8642617] | lr 0.3
# loss 0.005506487563252449 | grad_v [ 0.69167745 -0.72220665] | lr 0.3
# loss 0.005368374288082123 | grad_v [ 0.78102034 -0.6245055 ] | lr 0.3
# loss 0.005193154327571392 | grad_v [ 0.8240329  -0.56654197] | lr 0.3
# loss 0.004962299019098282 | grad_v [ 0.8433843  -0.53731066] | lr 0.3
# loss 0.00467729801312089 | grad_v [ 0.8481752  -0.52971566] | lr 0.3
# loss 0.004354081582278013 | grad_v [ 0.8417657  -0.53984296] | lr 0.3
# loss 0.004016428254544735 | grad_v [ 0.82446396 -0.56591445] | lr 0.3
# loss 0.003684846218675375 | grad_v [ 0.79478097 -0.6068964 ] | lr 0.3
# loss 0.003375690896064043 | grad_v [ 0.7479405  -0.66376585] | lr 0.3
# loss 0.0031000515446066856 | grad_v [ 0.67697835 -0.7360029 ] | lr 0.3
# loss 0.002861927030608058 | grad_v [ 0.57176954 -0.82041425] | lr 0.3
# loss 0.002660632599145174 | grad_v [ 0.42149866 -0.90682906] | lr 0.3
# loss 0.0024924911558628082 | grad_v [ 0.2226138 -0.9749067] | lr 0.3
# loss 0.002352601382881403 | grad_v [-0.00115609 -0.99999934] | lr 0.3
# loss 0.002234071958810091 | grad_v [-0.21425675 -0.97677743] | lr 0.3
# loss 0.002130077686160803 | grad_v [-0.38367477 -0.9234683 ] | lr 0.3
# loss 0.0020349102560430765 | grad_v [-0.50504494 -0.8630931 ] | lr 0.3

# %%
plt.figure(figsize=(5,3))

plt.plot(losses, label="loss position", color="green", linestyle="dashed")
# y axis log
plt.yscale("log")

plt.legend()

plt.title("Gradient descent")
plt.xlabel("optimization step")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
import matplotlib.patches as mpatches

plt.figure(figsize=(5,5))

plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

plt.grid()

for j in range(0, optimization_steps, 4):
    x = x0s[j, :].copy()
    v = v0s[j, :].copy()

    xs = jnp.zeros((n_iterations, 2), dtype=jnp.float32)
    vs = jnp.zeros((n_iterations, 2), dtype=jnp.float32)

    for i in range(n_iterations):
        x, v = verlet_step(x, v, dt, m, attractors)
        xs = xs.at[i, :].set(x.copy())
        vs = vs.at[i, :].set(v.copy())

    plt.scatter(xs[:,0], xs[:,1], c='red', marker='o', s=0.2, label='trajectory', alpha=0.3)

plt.scatter(attractors[:,0], attractors[:,1], c='orange', marker='o', s=40, label='attractor')  
plt.scatter(xn_star[0], xn_star[1], c='green', marker='x', s=40, label='target')
plt.scatter(x0_guess[0], x0_guess[1], c='blue', marker='x', s=40, label='initial position')

red_patch = mpatches.Patch(color='red', label='trajectories')
green_patch = mpatches.Patch(color='green', label='target position')
orange_patch = mpatches.Patch(color='orange', label='attractor')
blue_patch = mpatches.Patch(color='blue', label='initial position')
handles = [red_patch, green_patch, orange_patch, blue_patch]

plt.legend(handles=handles)
